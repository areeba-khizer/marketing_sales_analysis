# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\Tab & Tech\\Desktop\\notebook\\marketing_sales_data.csv')

# %%
df
# Out:
#          TV      Radio  Social Media Influencer       Sales
# 0       Low   3.518070      2.293790      Micro   55.261284
# 1       Low   7.756876      2.572287       Mega   67.574904
# 2      High  20.348988      1.227180      Micro  272.250108
# 3    Medium  20.108487      2.728374       Mega  195.102176
# 4      High  31.653200      7.776978       Nano  273.960377
# ..      ...        ...           ...        ...         ...
# 567  Medium  14.656633      3.817980      Micro  191.521266
# 568    High  28.110171      7.358169       Mega  297.626731
# 569  Medium  11.401084      5.818697       Nano  145.416851
# 570  Medium  21.119991      5.703028      Macro  209.326830
# 571     Low  13.221237      3.660566      Micro  135.773151
#
# [572 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# TV              0
# Radio           0
# Social Media    0
# Influencer      0
# Sales           0
# dtype: int64

# %%
sns.boxplot(x='TV', y='Sales', data=df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(x='Social Media', y='Sales', data=df)
# Out:
# <Axes: xlabel='Social Media', ylabel='Sales'>

# %%
sns.scatterplot(x='Radio', y='Sales', data=df)
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.boxplot(x='Influencer', y='Sales', data=df)
# Out:
# <Axes: xlabel='Influencer', ylabel='Sales'>

# %%
df['TV'] = df['TV'].map({'Low': 1, 'Medium': 2, 'High': 3})

# %%
df['Influencer'] = df['Influencer'].map({'Nano': 1, 'Micro': 2, 'Macro': 3, 'Mega': 4})

# %%
correlationtv = df['TV'].corr(df['Sales'])

# %%
correlationtv
# Out:
# 0.9331693110652562

# %%
correlationradio = df['Radio'].corr(df['Sales'])

# %%
correlationradio
# Out:
# 0.8580362615295892

# %%
correlationsocial = df['Social Media'].corr(df['Sales'])

# %%
correlationsocial
# Out:
# 0.542047760525807

# %%
correlationinfluencer = df['Influencer'].corr(df['Sales'])

# %%
correlationinfluencer
# Out:
# 0.0008467907846471051

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
